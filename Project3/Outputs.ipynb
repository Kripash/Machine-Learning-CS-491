# %%
import numpy as np
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
from math import log
from typing import Dict
from neural_network import *

# %%
np.random.seed(0)
X, y = make_moons(200, noise=0.2)
plt.scatter(X[:, 0], X[:, 1], s=40, c=y, cmap=plt.cm.Spectral)

# %%
plt.figure(figsize=(16,32))
hidden_layer_dimensions = [1, 2, 4, 5]
for i , nn_hdim in enumerate(hidden_layer_dimensions):
    plt.subplot(5, 2, i+1)
    plt.title('HiddenLayerSize%d' % nn_hdim)
    model = build_model(X, y, nn_hdim, print_loss=True)
    plot_decision_boundary(lambda x: predict(model, x), X, y)
plt.savefig('boundaries.jpg')
# Out:
# 0.6967345791454943
# 0.3281262273570383
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.3281262273570434
# 0.7030155105268898
# 0.27661462466350584
# 0.2617363302716971
# 0.2602237546162719
# 0.2594522969723813
# 0.25895160172547144
# 0.25858616050033145
# 0.258303699608656
# 0.2580769901789622
# 0.2578897716777824
# 0.257731806172277
# 0.25759633697405204
# 0.25747868850972977
# 0.2573754820040915
# 0.25728418568244676
# 0.2572028475094514
# 0.257129928945029
# 0.25706419634707717
# 0.2570046467925049
# 0.256950455510723
# 0.9729088801095129
# 0.06024875460862128
# 0.05717583864417009
# 0.05612517300145807
# 0.0549291723244768
# 0.054746682601340343
# 0.05399444447295145
# 0.06060275252413381
# 0.06098972344659307
# 0.06207686174466181
# 0.06215853085569556
# 0.06223811156873975
# 0.062313211848247334
# 0.062378926425047894
# 0.06243387248675365
# 0.06247843957736352
# 0.06251381783398963
# 0.06254150962133553
# 0.0625630752819797
# 0.06257996248568165
# 1.2746968427535963
# 0.061317550428312655
# 0.0596380373127184
# 0.04837195136531772
# 0.04424534785102093
# 0.04092395336340107
# 0.03840280442576353
# 0.034056756263733695
# 0.03307110437581609
# 0.0322136297390764
# 0.0316534732659805
# 0.03122821912968497
# 0.030908184330489606
# 0.03076822001875271
# 0.03028152150245408
# 0.030125006713464787
# 0.02984645621475903
# 0.02974835847869796
# 0.029510772143146152
# 0.029368638751579003
